# %% [markdown]
# <a href="https://colab.research.google.com/github/tejasrajguru2003-dot/Breast_Cancer_Classification/blob/main/Breast_Cancer_Classification_using__neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
import tensorflow as tf

# %%
import keras

# %%
import seaborn as sns

# %%
breast_cancer_data = pd.read_csv('/content/data-selected-columns.csv1.csv')

# %%
breast_cancer_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430

# %%
# Check for missing values
missing_values = breast_cancer_data.isnull().sum()
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# id                     0
# diagnosis              0
# radius_mean            0
# texture_mean           0
# perimeter_mean         0
# area_mean              0
# smoothness_mean        0
# compactness_mean       0
# concavity_mean         0
# concave points_mean    0
# dtype: int64

# %%
breast_cancer_data.shape
# Out:
# (569, 10)

# %%
breast_cancer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   569 non-null    int64
#  1   diagnosis            569 non-null    object
#  2   radius_mean          569 non-null    float64
#  3   texture_mean         569 non-null    float64
#  4   perimeter_mean       569 non-null    float64
#  5   area_mean            569 non-null    float64
#  6   smoothness_mean      569 non-null    float64
#  7   compactness_mean     569 non-null    float64
#  8   concavity_mean       569 non-null    float64
#  9   concave points_mean  569 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 44.6+ KB

# %%
breast_cancer_data.drop(columns='id',axis=1,inplace=True)

# %%
breast_cancer_data.isnull().sum()
# Out:
# diagnosis              0
# radius_mean            0
# texture_mean           0
# perimeter_mean         0
# area_mean              0
# smoothness_mean        0
# compactness_mean       0
# concavity_mean         0
# concave points_mean    0
# dtype: int64

# %%
breast_cancer_data.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200

# %%
breast_cancer_data['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
sns.countplot(x='diagnosis',data=breast_cancer_data)
# Out:
# <Axes: xlabel='diagnosis', ylabel='count'>

# %%
sns.displot(x='radius_mean',data=breast_cancer_data)

# %%
sns.displot(x='perimeter_mean',data=breast_cancer_data)

# %%
sns.displot(x='smoothness_mean',data=breast_cancer_data)

# %%
sns.displot(x='concavity_mean',data=breast_cancer_data)

# %%
sns.displot(x='texture_mean',data=breast_cancer_data)

# %%
sns.distplot(x=breast_cancer_data.radius_mean)
# Out:
# /tmp/ipykernel_554/4082491365.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=breast_cancer_data.radius_mean)
# <Axes: ylabel='Density'>

# %%
#pair plt
#sns. pairplot(df)
#plt.show

# %%
#select first column of the dataframe a series
first_column=breast_cancer_data.iloc[:,0]

#select second column of the dataframe a series
second_column=breast_cancer_data.iloc[:,0]

# %%
print(first_column)
print('-----')
print(second_column)
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object
# -----
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
plt.scatter(x=first_column,y=second_column)

# %%
for column in breast_cancer_data.select_dtypes(include=np.number).columns:
  plt.figure()
  breast_cancer_data.boxplot([column])

# %%
breast_cancer_data.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200

# %%
breast_cancer_data['diagnosis'] = breast_cancer_data['diagnosis'].map({'M': 1, 'B': 0})
correlation_matrix=breast_cancer_data.corr()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(correlation_matrix, cbar=True, fmt='.1f',annot=True,cmap='Blues')
plt.savefig('Correlation Heat Map')

# %%
from sklearn.preprocessing import LabelEncoder
lable_encode=LabelEncoder()

# %%
lables=lable_encode.fit_transform(breast_cancer_data['diagnosis'])

# %%
breast_cancer_data['target']=lables

# %%
breast_cancer_data.drop(columns='diagnosis',axis=1,inplace=True)

# %%
breast_cancer_data.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  target
# 0           0.27760          0.3001              0.14710       1
# 1           0.07864          0.0869              0.07017       1
# 2           0.15990          0.1974              0.12790       1
# 3           0.28390          0.2414              0.10520       1
# 4           0.13280          0.1980              0.10430       1

# %%
breast_cancer_data['target'].value_counts()
# Out:
# target
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
X = breast_cancer_data.drop(columns='target', axis=1)
Y = breast_cancer_data['target']

# %%
print(X)
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      compactness_mean  concavity_mean  concave points_mean
# 0             0.27760         0.30010              0.14710
# 1             0.07864         0.08690              0.07017
# 2             0.15990         0.19740              0.12790
# 3             0.28390         0.24140              0.10520
# 4             0.13280         0.19800              0.10430
# ..                ...             ...                  ...
# 564           0.11590         0.24390              0.13890
# 565           0.10340         0.14400              0.09791
# 566           0.10230         0.09251              0.05302
# 567           0.27700         0.35140              0.15200
# 568           0.04362         0.00000              0.00000
#
# [569 rows x 8 columns]

# %%
print(Y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: target, Length: 569, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (569, 8) (455, 8) (114, 8)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
tf.random.set_seed(3)

# %%
from tensorflow import keras

# %%
model = keras.Sequential([
                          keras.layers.Flatten(input_shape=(8,)),
                          keras.layers.Dense(20, activation='relu'),
                          keras.layers.Dense(2, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(X_train_std, Y_train, validation_split=0.1, epochs=10)
# Out:
# Epoch 1/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8362 - loss: 0.4389 - val_accuracy: 0.9130 - val_loss: 0.3462
# Epoch 2/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8851 - loss: 0.3673 - val_accuracy: 0.9130 - val_loss: 0.2971
# Epoch 3/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8949 - loss: 0.3163 - val_accuracy: 0.9348 - val_loss: 0.2629
# Epoch 4/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9120 - loss: 0.2790 - val_accuracy: 0.9130 - val_loss: 0.2390
# Epoch 5/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9193 - loss: 0.2510 - val_accuracy: 0.9348 - val_loss: 0.2216
# Epoch 6/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9267 - loss: 0.2294 - val_accuracy: 0.9130 - val_loss: 0.2087
# Epoch 7/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9340 - loss: 0.2122 - val_accuracy: 0.9348 - val_loss: 0.1984
# Epoch 8/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9413 - loss: 0.1984 - val_accuracy: 0.9348 - val_loss: 0.1903
# Epoch 9/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9389 - loss: 0.1869 - val_accuracy: 0.9130 - val_loss: 0.1838
# Epoch 10/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9389 - loss: 0.1774 - val_accuracy: 0.9130 - val_loss: 0.1787

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')

plt.legend(['training data', 'validation data'], loc = 'lower right')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')

plt.legend(['training data', 'validation data'], loc = 'upper right')

# %%
loss, accuracy = model.evaluate(X_test_std, Y_test)
print(accuracy)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9386 - loss: 0.1961
# 0.9385964870452881

# %%
print(X_test_std.shape)
print(X_test_std[0])
# Out:
# (114, 8)
# [-0.04462793 -1.41612656 -0.05903514 -0.16234067  2.0202457  -0.11323672
#   0.18500609  0.47102419]

# %%
Y_pred = model.predict(X_test_std)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
print(Y_pred.shape)
print(Y_pred[0])
# Out:
# (114, 2)
# [0.80750984 0.6780891 ]

# %%
print(Y_pred)
# Out:
# [[0.80750984 0.6780891 ]
#  [0.54529727 0.47435308]
#  [0.87862074 0.03809248]
#  [0.3239781  0.9996847 ]
#  [0.6651284  0.46204603]
#  [0.20920101 0.9897304 ]
#  [0.8182845  0.34065336]
#  [0.78072757 0.06582662]
#  [0.75758004 0.11840278]
#  [0.6725626  0.15850958]
#  [0.6578645  0.21667798]
#  [0.7910101  0.10551136]
#  [0.76923525 0.42198774]
#  [0.7018432  0.21004128]
#  [0.7776522  0.1053393 ]
#  [0.38602126 0.8323503 ]
#  [0.796624   0.07255138]
#  [0.8711051  0.2223465 ]
#  [0.81635106 0.07382063]
#  [0.40204722 0.9620393 ]
#  [0.93194556 0.9600897 ]
#  [0.810088   0.09718315]
#  [0.79340196 0.08343299]
#  [0.8385139  0.11977743]
#  [0.6980899  0.5182898 ]
#  [0.30531016 0.9319389 ]
#  [0.69929355 0.26499325]
#  [0.59797674 0.6448798 ]
#  [0.43681988 0.7928292 ]
#  [0.34543687 0.89624614]
#  [0.6763061  0.17978984]
#  [0.8173225  0.13082162]
#  [0.775686   0.14382763]
#  [0.31623492 0.9672788 ]
#  [0.2375716  0.98278475]
#  [0.6819059  0.3492852 ]
#  [0.8894122  0.04956016]
#  [0.76861966 0.14673044]
#  [0.86180735 0.10253301]
#  [0.85025525 0.17938802]
#  [0.19715998 0.9993741 ]
#  [0.48130125 0.6710984 ]
#  [0.90496993 0.05662916]
#  [0.8842507  0.24460934]
#  [0.6053494  0.864047  ]
#  [0.79312766 0.08276737]
#  [0.94255    0.06953187]
#  [0.8453156  0.08541925]
#  [0.34102535 0.89532775]
#  [0.3510697  0.91955227]
#  [0.6787587  0.15874511]
#  [0.42963138 0.7526575 ]
#  [0.53466463 0.5230534 ]
#  [0.78824943 0.09963216]
#  [0.8927654  0.10486671]
#  [0.5818179  0.37003124]
#  [0.81539255 0.14192693]
#  [0.934356   0.08937515]
#  [0.9185543  0.9932289 ]
#  [0.8882403  0.1588389 ]
#  [0.74595356 0.3310369 ]
#  [0.5153832  0.9797296 ]
#  [0.8159212  0.12683374]
#  [0.36477652 0.9773561 ]
#  [0.4443627  0.81268203]
#  [0.68825495 0.95686775]
#  [0.3201724  0.9218345 ]
#  [0.42365584 0.9509427 ]
#  [0.6201258  0.3229516 ]
#  [0.8039561  0.8728799 ]
#  [0.49497804 0.9596421 ]
#  [0.4565324  0.96371776]
#  [0.7571419  0.1294368 ]
#  [0.52039385 0.843332  ]
#  [0.908943   0.07944193]
#  [0.44516867 0.90994984]
#  [0.87534416 0.08951414]
#  [0.8645402  0.10651948]
#  [0.6893144  0.2971773 ]
#  [0.5839105  0.7037779 ]
#  [0.3087772  0.97783774]
#  [0.43650055 0.78407943]
#  [0.39176464 0.94652534]
#  [0.7832473  0.24795003]
#  [0.7538755  0.14025182]
#  [0.6673955  0.3921614 ]
#  [0.8619653  0.3990628 ]
#  [0.87463504 0.1821338 ]
#  [0.8512481  0.2881622 ]
#  [0.46722952 0.9978805 ]
#  [0.87321997 0.1584125 ]
#  [0.62677443 0.22370936]
#  [0.8288257  0.2109577 ]
#  [0.2826478  0.95773494]
#  [0.4921773  0.57884   ]
#  [0.8517043  0.30760023]
#  [0.33658558 0.96870273]
#  [0.35137513 0.9165071 ]
#  [0.76590234 0.1728463 ]
#  [0.8325193  0.04523047]
#  [0.8732928  0.03249208]
#  [0.75670034 0.80493367]
#  [0.259448   0.9663543 ]
#  [0.19335233 0.9965221 ]
#  [0.8199923  0.08400719]
#  [0.846093   0.10336569]
#  [0.9190101  0.18609487]
#  [0.9318259  0.14908344]
#  [0.9258367  0.04493656]
#  [0.7961146  0.19868104]
#  [0.2749241  0.9490225 ]
#  [0.41188246 0.9231722 ]
#  [0.6401503  0.36846322]
#  [0.45403585 0.95106834]]

# %%
input_data = (11.76,21.6,74.72,427.9,0.08637,0.04966,0.01657,0.01115)

# change the input_data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the numpy array as we are predicting for one data point
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# standardizing the input data
input_data_std = scaler.transform(input_data_reshaped)

prediction = model.predict(input_data_std)
print(prediction)

prediction_label = [np.argmax(prediction)]
print(prediction_label)

if(prediction_label[0] == 0):
  print('The tumor is Malignant')

else:
  print('The tumor is Benign')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# [[0.810274   0.07038242]]
# [np.int64(0)]
# The tumor is Malignant
